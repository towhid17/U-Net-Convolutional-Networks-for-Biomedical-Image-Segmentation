# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate
from keras.losses import CategoricalCrossentropy

# %%
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)   #Not in the original network. 
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)  #Not in the original network
    x = Activation("relu")(x)

    return x

# %%
def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

# %%
def decoder_block(input, skip_features, num_filters):
    # x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = UpSampling2D(size=(2, 2))(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %%
def build_unet(input_shape, n_classes):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024) #Bridge

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    if n_classes == 1:
      activation = 'sigmoid'
    else:
      activation = 'softmax'

    outputs = Conv2D(n_classes, 1, padding="same", activation=activation)(d4)  

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
my_unet = build_unet(input_shape=(512,512,3), n_classes=4)
print(my_unet.summary())
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_39 (Conv2D)             (None, 512, 512, 64  1792        ['input_4[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 512, 512, 64  256        ['conv2d_39[0][0]']
#  ormalization)                  )
#
#  activation_38 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_38[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 512, 512, 64  36928       ['activation_38[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 512, 512, 64  256        ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  activation_39 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 256, 256, 64  0          ['activation_39[0][0]']
#  )                              )
#
#  conv2d_41 (Conv2D)             (None, 256, 256, 12  73856       ['max_pooling2d_12[0][0]']
#                                 8)
#
#  batch_normalization_40 (BatchN  (None, 256, 256, 12  512        ['conv2d_41[0][0]']
#  ormalization)                  8)
#
#  activation_40 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_40[0][0]']
#                                 8)
#
#  conv2d_42 (Conv2D)             (None, 256, 256, 12  147584      ['activation_40[0][0]']
#                                 8)
#
#  batch_normalization_41 (BatchN  (None, 256, 256, 12  512        ['conv2d_42[0][0]']
#  ormalization)                  8)
#
#  activation_41 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_41[0][0]']
#                                 8)
#
#  max_pooling2d_13 (MaxPooling2D  (None, 128, 128, 12  0          ['activation_41[0][0]']
#  )                              8)
#
#  conv2d_43 (Conv2D)             (None, 128, 128, 25  295168      ['max_pooling2d_13[0][0]']
#                                 6)
#
#  batch_normalization_42 (BatchN  (None, 128, 128, 25  1024       ['conv2d_43[0][0]']
#  ormalization)                  6)
#
#  activation_42 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_42[0][0]']
#                                 6)
#
#  conv2d_44 (Conv2D)             (None, 128, 128, 25  590080      ['activation_42[0][0]']
#                                 6)
#
#  batch_normalization_43 (BatchN  (None, 128, 128, 25  1024       ['conv2d_44[0][0]']
#  ormalization)                  6)
#
#  activation_43 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_43[0][0]']
#                                 6)
#
#  max_pooling2d_14 (MaxPooling2D  (None, 64, 64, 256)  0          ['activation_43[0][0]']
#  )
#
#  conv2d_45 (Conv2D)             (None, 64, 64, 512)  1180160     ['max_pooling2d_14[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_45[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 32, 32, 512)  0          ['activation_45[0][0]']
#  )
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 1024  4719616     ['max_pooling2d_15[0][0]']
#                                 )
#
#  batch_normalization_46 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_47[0][0]']
#  ormalization)                  )
#
#  activation_46 (Activation)     (None, 32, 32, 1024  0           ['batch_normalization_46[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 1024  9438208     ['activation_46[0][0]']
#                                 )
#
#  batch_normalization_47 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_48[0][0]']
#  ormalization)                  )
#
#  activation_47 (Activation)     (None, 32, 32, 1024  0           ['batch_normalization_47[0][0]']
#                                 )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 1024  0          ['activation_47[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 1536  0           ['up_sampling2d_1[0][0]',
#                                 )                                 'activation_45[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 64, 64, 512)  7078400     ['concatenate_6[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_49[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 51  0          ['activation_49[0][0]']
#                                 2)
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 76  0           ['up_sampling2d_2[0][0]',
#                                 8)                                'activation_43[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 128, 128, 25  1769728     ['concatenate_7[0][0]']
#                                 6)
#
#  batch_normalization_50 (BatchN  (None, 128, 128, 25  1024       ['conv2d_51[0][0]']
#  ormalization)                  6)
#
#  activation_50 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_50[0][0]']
#                                 6)
#
#  conv2d_52 (Conv2D)             (None, 128, 128, 25  590080      ['activation_50[0][0]']
#                                 6)
#
#  batch_normalization_51 (BatchN  (None, 128, 128, 25  1024       ['conv2d_52[0][0]']
#  ormalization)                  6)
#
#  activation_51 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_51[0][0]']
#                                 6)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 25  0          ['activation_51[0][0]']
#                                 6)
#
#  concatenate_8 (Concatenate)    (None, 256, 256, 38  0           ['up_sampling2d_3[0][0]',
#                                 4)                                'activation_41[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 256, 256, 12  442496      ['concatenate_8[0][0]']
#                                 8)
#
#  batch_normalization_52 (BatchN  (None, 256, 256, 12  512        ['conv2d_53[0][0]']
#  ormalization)                  8)
#
#  activation_52 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_52[0][0]']
#                                 8)
#
#  conv2d_54 (Conv2D)             (None, 256, 256, 12  147584      ['activation_52[0][0]']
#                                 8)
#
#  batch_normalization_53 (BatchN  (None, 256, 256, 12  512        ['conv2d_54[0][0]']
#  ormalization)                  8)
#
#  activation_53 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_53[0][0]']
#                                 8)
#
#  up_sampling2d_4 (UpSampling2D)  (None, 512, 512, 12  0          ['activation_53[0][0]']
#                                 8)
#
#  concatenate_9 (Concatenate)    (None, 512, 512, 19  0           ['up_sampling2d_4[0][0]',
#                                 2)                                'activation_39[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 512, 512, 64  110656      ['concatenate_9[0][0]']
#                                 )
#
#  batch_normalization_54 (BatchN  (None, 512, 512, 64  256        ['conv2d_55[0][0]']
#  ormalization)                  )
#
#  activation_54 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_54[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 512, 512, 64  36928       ['activation_54[0][0]']
#                                 )
#
#  batch_normalization_55 (BatchN  (None, 512, 512, 64  256        ['conv2d_56[0][0]']
#  ormalization)                  )
#
#  activation_55 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_55[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 512, 512, 4)  260         ['activation_55[0][0]']
#
# ==================================================================================================
# Total params: 31,402,692
# Trainable params: 31,390,916
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
# None

# %%
my_unet.compile(optimizer=Adam(learning_rate = 1e-3), loss='categorical ', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 my_unet.compile(optimizer=Adam(learning_rate = 1e-3), loss=CategoricalCrossentropy(), metrics=['accuracy'])
#
# NameError: name 'CategoricalCrossentropy' is not defined
